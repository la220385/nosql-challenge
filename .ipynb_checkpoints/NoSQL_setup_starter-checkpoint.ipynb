# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with: mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/anaconda3/lib/python3.12/site-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

# Replace 'path_to_file.json' with the path to your establishments.json file
with open('Resources/establishments.json', 'r') as file:
    data = json.load(file)

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/")
db = client['uk_food']
collection = db['establishments']

# %%
collection.drop()  # Drop the collection if it exists
collection.insert_many(data)  # Insert the JSON data
# Out:
# InsertManyResult([ObjectId('677c293d4da991a183e91c0b'), ObjectId('677c293d4da991a183e91c0c'), ObjectId('677c293d4da991a183e91c0d'), ObjectId('677c293d4da991a183e91c0e'), ObjectId('677c293d4da991a183e91c0f'), ObjectId('677c293d4da991a183e91c10'), ObjectId('677c293d4da991a183e91c11'), ObjectId('677c293d4da991a183e91c12'), ObjectId('677c293d4da991a183e91c13'), ObjectId('677c293d4da991a183e91c14'), ObjectId('677c293d4da991a183e91c15'), ObjectId('677c293d4da991a183e91c16'), ObjectId('677c293d4da991a183e91c17'), ObjectId('677c293d4da991a183e91c18'), ObjectId('677c293d4da991a183e91c19'), ObjectId('677c293d4da991a183e91c1a'), ObjectId('677c293d4da991a183e91c1b'), ObjectId('677c293d4da991a183e91c1c'), ObjectId('677c293d4da991a183e91c1d'), ObjectId('677c293d4da991a183e91c1e'), ObjectId('677c293d4da991a183e91c1f'), ObjectId('677c293d4da991a183e91c20'), ObjectId('677c293d4da991a183e91c21'), ObjectId('677c293d4da991a183e91c22'), ObjectId('677c293d4da991a183e91c23'), ObjectId('677c293d4da991a183e91c24'), ObjectId('677c293d4da991a183e91c25'), ObjectId('677c293d4da991a183e91c26'), ObjectId('677c293d4da991a183e91c27'), ObjectId('677c293d4da991a183e91c28'), ObjectId('677c293d4da991a183e91c29'), ObjectId('677c293d4da991a183e91c2a'), ObjectId('677c293d4da991a183e91c2b'), ObjectId('677c293d4da991a183e91c2c'), ObjectId('677c293d4da991a183e91c2d'), ObjectId('677c293d4da991a183e91c2e'), ObjectId('677c293d4da991a183e91c2f'), ObjectId('677c293d4da991a183e91c30'), ObjectId('677c293d4da991a183e91c31'), ObjectId('677c293d4da991a183e91c32'), ObjectId('677c293d4da991a183e91c33'), ObjectId('677c293d4da991a183e91c34'), ObjectId('677c293d4da991a183e91c35'), ObjectId('677c293d4da991a183e91c36'), ObjectId('677c293d4da991a183e91c37'), ObjectId('677c293d4da991a183e91c38'), ObjectId('677c293d4da991a183e91c39'), ObjectId('677c293d4da991a183e91c3a'), ObjectId('677c293d4da991a183e91c3b'), ObjectId('677c293d4da991a183e91c3c'), ObjectId('677c293d4da991a183e91c3d'), ObjectId('677c293d4da991a183e91c3e'), ObjectId('677c293
db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName": "Penang Flavours",
    "BusinessType": "Restaurant/Cafe/Canteen",
    "BusinessTypeID": "",
    "AddressLine1": "Penang Flavours",
    "AddressLine2": "146A Plumstead Rd",
    "AddressLine3": "London",
    "AddressLine4": "",
    "PostCode": "SE18 7DY",
    "Phone": "",
    "LocalAuthorityCode": "511",
    "LocalAuthorityName": "Greenwich",
    "LocalAuthorityWebSite": "http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress": "health@royalgreenwich.gov.uk",
    "scores": {
        "Hygiene": "",
        "Structural": "",
        "ConfidenceInManagement": ""
    },
    "SchemeType": "FHRS",
    "geocode": {
        "longitude": "0.08384000",
        "latitude": "51.49014200"
    },
    "RightToReply": "",
    "Distance": 4623.9723280747176,
    "NewRatingPending": True
}

# %%
# Insert the new restaurant into the collection
db.establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('677c293e4da991a183e9b76f'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
inserted_restaurant = db.establishments.find_one({"BusinessName": "Penang Flavours"})
print(inserted_restaurant)
# Out:
# {'_id': ObjectId('677c293e4da991a183e9b76f'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_type_query = {"BusinessType": "Restaurant/Cafe/Canteen"}
business_type = establishments_collection.find_one(business_type_query, {"BusinessTypeID": 1, "BusinessType": 1})
business_type_id = business_type['BusinessTypeID']

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
update_query = {"BusinessName": "Penang Flavours"}
update_values = {"$set": {"BusinessTypeID": business_type_id}}
establishments_collection.update_one(update_query, update_values)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
updated_restaurant = establishments_collection.find_one(update_query)
print(updated_restaurant)
# Out:
# {'_id': ObjectId('677c293e4da991a183e9b76f'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
count_dover = establishments_collection.count_documents({"LocalAuthorityName": "Dover"})
print(f"Number of documents with LocalAuthorityName 'Dover': {count_dover}")
# Out:
# Number of documents with LocalAuthorityName 'Dover': 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments_collection.delete_many({"LocalAuthorityName": "Dover"})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
remaining_dover_count = establishments_collection.count_documents({"LocalAuthorityName": "Dover"})
print(f"Remaining documents with LocalAuthorityName 'Dover': {remaining_dover_count}")
# Out:
# Remaining documents with LocalAuthorityName 'Dover': 0

# %%
# Check that other documents remain with 'find_one'
other_document = establishments_collection.find_one({"LocalAuthorityName": {"$ne": "Dover"}})
print(other_document)
# Out:
# {'_id': ObjectId('677c293d4da991a183e91ef2'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.195625', 'latitude': '51.083812'}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many(
    {},
    [
        {'$set': {
            "geocode.latitude": {'$toDouble': "$geocode.latitude"},
            "geocode.longitude": {'$toDouble': "$geocode.longitude"}
        }}
    ]
)
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many(
    {},
    [
        {'$set': {
            "RatingValue": {'$toInt': "$RatingValue"}
        }}
    ]
)
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
sample_document = establishments.find_one()
print(f"Latitude: {sample_document['geocode']['latitude']}, Type: {type(sample_document['geocode']['latitude'])}")
print(f"Longitude: {sample_document['geocode']['longitude']}, Type: {type(sample_document['geocode']['longitude'])}")
print(f"RatingValue: {sample_document['RatingValue']}, Type: {type(sample_document['RatingValue'])}")
# Out:
# Latitude: 51.083812, Type: <class 'float'>
# Longitude: 1.195625, Type: <class 'float'>
# RatingValue: 5, Type: <class 'int'>
